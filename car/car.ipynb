# %%
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
data = pd.read_csv('car_price_ml_data.csv')

# %%
data.head()
# Out:
#                                  Car ID Manufacturer Model Name  \
# 0  2677d47a-adf7-467f-ab57-650b7e913c80       Toyota      north
# 1  556f50b7-e1b3-44e8-ac42-6491ec72d10f       Toyota       most
# 2  b88ccf85-2198-4b98-93c1-e007c2ab8c7e      Hyundai       part
# 3  5b3d4e5f-de42-4886-8178-dceb27dd8e93       Toyota      truth
# 4  0b578609-729e-4df5-acd9-ef1312ebd06a        Honda    kitchen
#
#    Year of Manufacture Fuel Type Transmission Type  Mileage (kmpl)  \
# 0                 2003    Diesel            Manual             8.9
# 1                 2008    Hybrid            Manual            12.9
# 2                 2007    Petrol         Automatic            20.5
# 3                 2005    Petrol         Automatic            10.7
# 4                 2005    Diesel            Manual            30.7
#
#    Engine Displacement (cc)  Max Power (bhp)  Seating Capacity  \
# 0                       950            215.7                 4
# ...

# %%
data.dtypes
# Out:
# Car ID                             object
# Manufacturer                       object
# Model Name                         object
# Year of Manufacture                 int64
# Fuel Type                          object
# Transmission Type                  object
# Mileage (kmpl)                    float64
# Engine Displacement (cc)            int64
# Max Power (bhp)                   float64
# Seating Capacity                    int64
# Number of Doors                     int64
# Length (mm)                       float64
# Width (mm)                          int64
# Height (mm)                         int64
# Boot Space (litres)               float64
# Fuel Tank Capacity (litres)         int64
# Body Type                          object
# Color                              object
# Owner Type                         object
# Insurance Status                   object
# Service History Available          object
# Accident History                   object
# ...

# %%
data.isnull().sum()
# Out:
# Car ID                               0
# Manufacturer                         0
# Model Name                           0
# Year of Manufacture                  0
# Fuel Type                            0
# Transmission Type                 1000
# Mileage (kmpl)                       0
# Engine Displacement (cc)             0
# Max Power (bhp)                      0
# Seating Capacity                     0
# Number of Doors                      0
# Length (mm)                       1000
# Width (mm)                           0
# Height (mm)                          0
# Boot Space (litres)               1000
# Fuel Tank Capacity (litres)          0
# Body Type                            0
# Color                                0
# Owner Type                           0
# Insurance Status                     0
# Service History Available            0
# Accident History                     0
# City                                 0
# State                                0
# ...

# %%
data['Boot Space (litres)'].fillna(data['Boot Space (litres)'].mean(),inplace=True)

# %%
data['Length (mm)'].fillna(data['Length (mm)'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Car ID                               0
# Manufacturer                         0
# Model Name                           0
# Year of Manufacture                  0
# Fuel Type                            0
# Transmission Type                 1000
# Mileage (kmpl)                       0
# Engine Displacement (cc)             0
# Max Power (bhp)                      0
# Seating Capacity                     0
# Number of Doors                      0
# Length (mm)                          0
# Width (mm)                           0
# Height (mm)                          0
# Boot Space (litres)                  0
# Fuel Tank Capacity (litres)          0
# Body Type                            0
# Color                                0
# Owner Type                           0
# Insurance Status                     0
# Service History Available            0
# Accident History                     0
# City                                 0
# State                                0
# ...

# %%
data.dropna(how = 'any', inplace=True)

# %%
data.isnull().sum()
# Out:
# Car ID                            0
# Manufacturer                      0
# Model Name                        0
# Year of Manufacture               0
# Fuel Type                         0
# Transmission Type                 0
# Mileage (kmpl)                    0
# Engine Displacement (cc)          0
# Max Power (bhp)                   0
# Seating Capacity                  0
# Number of Doors                   0
# Length (mm)                       0
# Width (mm)                        0
# Height (mm)                       0
# Boot Space (litres)               0
# Fuel Tank Capacity (litres)       0
# Body Type                         0
# Color                             0
# Owner Type                        0
# Insurance Status                  0
# Service History Available         0
# Accident History                  0
# City                              0
# State                             0
# Country                           0
# Seller Type                       0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
data['Manufacturer'] = label.fit_transform(data['Manufacturer'])
