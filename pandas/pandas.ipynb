# %%
import pandas as pd

# %%
data = [1,2,3,4,5]
index = ['a','b','c','d','e']
series = pd.Series(data, index=index)
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ['c0','c1','c2'], index = ['r0','r1','r2'])
df
# Out:
#     c0  c1  c2
# r0   1   2   3
# r1   4   5   6
# r2   7   8   9

# %%
data = pd.read_csv('obesity_prediction.csv')

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.tail()
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 2106  Sometimes    no  1.728139  no  1.676269  0.906247  Sometimes
# 2107  Sometimes    no  2.005130  no  1.341390  0.599270  Sometimes
# 2108  Sometimes    no  2.054193  no  1.414209  0.646288  Sometimes
# 2109  Sometimes    no  2.852339  no  1.139107  0.586035  Sometimes
# 2110  Sometimes    no  2.863513  no  1.026452  0.714137  Sometimes
#
#                      MTRANS           Obesity
# 2106  Public_Transportation  Obesity_Type_III
# ...

# %%
data.sample()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 26   Male  21.0     1.7    65.0            yes  yes   2.0  1.0  Frequently
#
#    SMOKE  CH2O SCC  FAF  TUE    CALC   MTRANS        Obesity
# 26    no   2.0  no  1.0  2.0  Always  Walking  Normal_Weight

# %%
data.sample(10,random_state=5)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 866   Female  18.000000  1.498561   55.376512             no  yes  2.000000
# 217     Male  21.000000  1.710000   75.000000             no   no  2.000000
# 1908  Female  20.871667  1.782453  137.852618            yes  yes  3.000000
# 1972  Female  18.301773  1.808765  140.292018            yes  yes  3.000000
# 1849  Female  26.000000  1.602025  104.899348            yes  yes  3.000000
# 1554    Male  21.963787  1.849601  122.333425            yes  yes  3.000000
# 1446    Male  21.797388  1.775584  103.605896            yes  yes  2.121909
# 424     Male  33.000000  1.740000   76.000000             no   no  2.000000
# 247   Female  20.000000  1.620000   52.000000             no  yes  3.000000
# 1752    Male  27.266287  1.828276  120.872294            yes  yes  2.637202
#
#            NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# ...

# %%
data.columns.tolist()
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'Obesity']

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2111, step=1)

# %%
data.shape
# Out:
# (2111, 17)

# %%
data.size
# Out:
# 35887

# %%
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %%
data.loc[0,'Age']
# Out:
# np.float64(21.0)

# %%
kdata.iloc[0:7, 0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 kdata.iloc[0:7, 0:5]
#
# NameError: name 'kdata' is not defined

# %%
#data.loc[data['weight']<50]

# %%
data.iloc[0:10, 0:5]
# Out:
#    Gender   Age  Height  Weight family_history
# 0  Female  21.0    1.62    64.0            yes
# 1  Female  21.0    1.52    56.0            yes
# 2    Male  23.0    1.80    77.0            yes
# 3    Male  27.0    1.80    87.0             no
# 4    Male  22.0    1.78    89.8             no
# 5    Male  29.0    1.62    53.0             no
# 6  Female  23.0    1.50    55.0            yes
# 7    Male  22.0    1.64    53.0             no
# 8    Male  24.0    1.78    64.0            yes
# 9    Male  22.0    1.72    68.0            yes

# %%
data.at[0,'Age']
# Out:
# np.float64(21.0)

# %%
data.iat[0,5]
# Out:
# 'no'

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.loc[data['Height']>1]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
data.loc[data['Weight']<50]
# Out:
#      Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 36   Female  22.000000  1.560000  49.000000             no  yes  2.000000
# 37   Female  21.000000  1.600000  48.000000             no  yes  2.000000
# 51   Female  20.000000  1.500000  44.000000             no  yes  2.000000
# 60   Female  21.000000  1.550000  49.000000            yes  yes  2.000000
# 75   Female  23.000000  1.630000  45.000000            yes   no  3.000000
# ..      ...        ...       ...        ...            ...  ...       ...
# 737  Female  19.269079  1.580920  44.753943             no   no  3.000000
# 738  Female  19.946244  1.603435  45.000000             no   no  3.000000
# 739  Female  19.639431  1.535350  42.000000             no  yes  3.000000
# 740  Female  19.000000  1.531610  42.000000             no  yes  2.749268
# 741  Female  19.434709  1.525691  42.000000             no  yes  3.000000
#
#           NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# ...

# %%
data.loc[(data['Weight']<50) & (data['Obesity'] == 'Normal_Weight')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 36   Female  22.0    1.56    49.0             no  yes   2.0  3.0   Sometimes
# 37   Female  21.0    1.60    48.0             no  yes   2.0  3.0   Sometimes
# 51   Female  20.0    1.50    44.0             no  yes   2.0  3.0   Sometimes
# 60   Female  21.0    1.55    49.0            yes  yes   2.0  3.0   Sometimes
# 94   Female  24.0    1.60    48.0             no  yes   3.0  3.0   Sometimes
# 113  Female  22.0    1.50    49.0            yes   no   2.0  1.0   Sometimes
# 156  Female  35.0    1.53    45.0            yes   no   3.0  3.0  Frequently
# 176  Female  18.0    1.57    48.0            yes  yes   3.0  1.0      Always
# 180  Female  18.0    1.58    48.0             no  yes   2.0  3.0   Sometimes
# 218  Female  21.0    1.50    42.3            yes   no   1.0  1.0   Sometimes
# 234  Female  19.0    1.59    49.0            yes  yes   2.0  1.0          no
# ...

# %%
data.loc[:,'SMOKE'] = 'yes'

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0   yes   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2   yes   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3   yes   2.0   no  2.0  0.0  Frequently                Walking
# 4   yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.loc[:2, 'SMOKE'] = 'may be'

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  may be   2.0   no  0.0  1.0          no  Public_Transportation
# 1  may be   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  may be   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3     yes   2.0   no  2.0  0.0  Frequently                Walking
# 4     yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.iloc[1,4] = 'no data'

# %%
def increment_age_by_5(x):
    return x+5

data['Age'] = data['Age'].apply(increment_age_by_5)

data['Age']
# Out:
# 0       26.000000
# 1       26.000000
# 2       28.000000
# 3       32.000000
# 4       27.000000
#           ...
# 2106    25.976842
# 2107    26.982942
# 2108    27.524036
# 2109    29.361936
# 2110    28.664709
# Name: Age, Length: 2111, dtype: float64

# %%
data['Age'] = data['Age'].apply(lambda x : x-5)

data['Age']
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
#data.drop(columns='BMI',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data.drop(columns='BMI',inplace = True)
#
# File c:\Users\sharm\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
data.insert(2,'BMI',data['Weight']/data['Height']**2)

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0        no data   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  may be   2.0   no  0.0  1.0          no  Public_Transportation
# 1  may be   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  may be   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3     yes   2.0   no  2.0  0.0  Frequently                Walking
# 4     yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.drop(columns = 'BMI')
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000        no data   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
data.drop(columns=['BMI'],inplace=True)

# %%
#data.rename(column =('Obesity':'Category'),inplace = True)
# Out:
#   Cell In[82], line 1
#     data.rename(column =('Obesity':'Category'),inplace = True)
#                                   ^
# SyntaxError: invalid syntax

# %%
df1 = pd.DataFrame({
    'id' : [1,2,3,4],
    'name' : ['Gargi','Amit','Mahi','Sakshee']
})

df2 = pd.DataFrame({
    'id' : [5,6,7,8],
    'course' : ['GenAI','CPP','HLD','LLD']

})

inner_result = pd.merge(df1,df2, how='inner',on='id')
inner_result
# Out:
# Empty DataFrame
# Columns: [id, name, course]
# Index: []

# %%
outer_result = pd.merge(df1,df2,how='outer',on='id')

# %%
outer_result
# Out:
#    id     name  course
# 0   1    Gargi     NaN
# 1   2     Amit     NaN
# 2   3     Mahi     NaN
# 3   4  Sakshee     NaN
# 4   5      NaN  GentAI
# 5   6      NaN     CPP
# 6   7      NaN     HLD
# 7   8      NaN     LLD

# %%
left_result = pd.merge(df1,df2 ,how='left',on='id')
left_result
# Out:
#    id     name course
# 0   1    Gargi    NaN
# 1   2     Amit    NaN
# 2   3     Mahi    NaN
# 3   4  Sakshee    NaN

# %%
right_result = pd.merge(df1,df2 ,how='right',on='id')
right_result
# Out:
#    id name  course
# 0   5  NaN  GentAI
# 1   6  NaN     CPP
# 2   7  NaN     HLD
# 3   8  NaN     LLD

# %%
df3 = pd.DataFrame({
    'id1' : [1,2,3,4],
    'name' : ['Gargi','Amit','Mahi','Sakshee']
})

df4 = pd.DataFrame({
    'id2' : [5,6,7,8],
    'course' : ['GenAI','CPP','HLD','LLD']

})

inner_result = pd.merge(df3,df4, how='inner',left_on='id1',right_on='id2')
inner_result
# Out:
# Empty DataFrame
# Columns: [id1, name, id2, course]
# Index: []

# %%
df3 = pd.DataFrame({
    'id1' : [1,2,3,4],
    'name' : ['Gargi','Amit','Mahi','Sakshee']
})

df4 = pd.DataFrame({
    'id2' : [5,6,7,8],
    'course' : ['GenAI','CPP','HLD','LLD']

})

result = pd.concat([df1,df2], axis=0)
result
# Out:
#    id1     name  id2  course
# 0  1.0    Gargi  NaN     NaN
# 1  2.0     Amit  NaN     NaN
# 2  3.0     Mahi  NaN     NaN
# 3  4.0  Sakshee  NaN     NaN
# 0  NaN      NaN  5.0  GentAI
# 1  NaN      NaN  6.0     CPP
# 2  NaN      NaN  7.0     HLD
# 3  NaN      NaN  8.0     LLD

# %%
df3 = pd.DataFrame({
    'id1' : [1,2,3,4],
    'name' : ['Gargi','Amit','Mahi','Sakshee']
})

df4 = pd.DataFrame({
    'id2' : [5,6,7,8],
    'course' : ['GenAI','CPP','HLD','LLD']

})

result = pd.concat([df1,df2], axis=0, ignore_index=True)
result
# Out:
#    id1     name  id2  course
# 0  1.0    Gargi  NaN     NaN
# 1  2.0     Amit  NaN     NaN
# 2  3.0     Mahi  NaN     NaN
# 3  4.0  Sakshee  NaN     NaN
# 4  NaN      NaN  5.0  GentAI
# 5  NaN      NaN  6.0     CPP
# 6  NaN      NaN  7.0     HLD
# 7  NaN      NaN  8.0     LLD

# %%
result2 = pd.concat([df1,df2], axis=1 )
result2
# Out:
#    id1     name  id2  course
# 0    1    Gargi    5  GentAI
# 1    2     Amit    6     CPP
# 2    3     Mahi    7     HLD
# 3    4  Sakshee    8     LLD

# %%
result3 = pd.concat([df1,df2], axis=0, keys=['df1','df2'])
result3
# Out:
#        id1     name  id2  course
# df1 0  1.0    Gargi  NaN     NaN
#     1  2.0     Amit  NaN     NaN
#     2  3.0     Mahi  NaN     NaN
#     3  4.0  Sakshee  NaN     NaN
# df2 0  NaN      NaN  5.0  GentAI
#     1  NaN      NaN  6.0     CPP
#     2  NaN      NaN  7.0     HLD
#     3  NaN      NaN  8.0     LLD

# %%
result3.isna()
# Out:
#          id1   name    id2  course
# df1 0  False  False   True    True
#     1  False  False   True    True
#     2  False  False   True    True
#     3  False  False   True    True
# df2 0   True   True  False   False
#     1   True   True  False   False
#     2   True   True  False   False
#     3   True   True  False   False

# %%
result3.notna()
# Out:
#          id1   name    id2  course
# df1 0   True   True  False   False
#     1   True   True  False   False
#     2   True   True  False   False
#     3   True   True  False   False
# df2 0  False  False   True    True
#     1  False  False   True    True
#     2  False  False   True    True
#     3  False  False   True    True

# %%
result3.isna().sum()
# Out:
# id1       4
# name      4
# id2       4
# course    4
# dtype: int64

# %%
result3.notna().sum()
# Out:
# id1       4
# name      4
# id2       4
# course    4
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0        no data   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  may be   2.0   no  0.0  1.0          no  Public_Transportation
# 1  may be   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  may be   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3     yes   2.0   no  2.0  0.0  Frequently                Walking
# 4     yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0        no data   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  may be   2.0   no  0.0  1.0          no  Public_Transportation
# 1  may be   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  may be   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3     yes   2.0   no  2.0  0.0  Frequently                Walking
# 4     yes   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
data.groupby('Gender').count()
# Out:
#          Age  Height  Weight  family_history  FAVC  FCVC   NCP  CAEC  SMOKE  \
# Gender
# Female  1043    1043    1043            1043  1043  1043  1043  1043   1043
# Male    1068    1068    1068            1068  1068  1068  1068  1068   1068
#
#         CH2O   SCC   FAF   TUE  CALC  MTRANS  Obesity
# Gender
# Female  1043  1043  1043  1043  1043    1043     1043
# Male    1068  1068  1068  1068  1068    1068     1068

# %%
data.groupby('Gender')['Weight'].mean()
# Out:
# Gender
# Female    82.302364
# Male      90.769478
# Name: Weight, dtype: float64

# %%
data.groupby('Gender')['Weight'].median()
# Out:
# Gender
# Female    78.00000
# Male      89.94547
# Name: Weight, dtype: float64

# %%
data.groupby('Gender')['Weight'].agg(['sum','mean'])
# Out:
#                  sum       mean
# Gender
# Female  85841.365833  82.302364
# Male    96941.802872  90.769478
