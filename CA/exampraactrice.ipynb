# %%
import pandas as pd 
import seaborn as sns
import numpy as numpy 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("heart_attack_russia_youth_vs_adult.csv")
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_15040\1901410569.py:1: DtypeWarning: Columns (9,11,12,14,15,16,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("heart_attack_russia_youth_vs_adult.csv")

# %%
data.head(10)
# Out:
#      ID  Age  Gender    Region  Blood_Pressure  Cholesterol   BMI  Heart_Rate  \
# 0   1.0   50    Male     Rural           110.0        196.5  15.9        76.0
# 1   2.0   40  Female     Urban           138.8        157.5  27.1        82.0
# 2   3.0   26    Male     Rural           116.0        210.1  27.2        71.0
# 3   4.0   54  Female     Rural           133.5        170.5  26.0        74.0
# 4   5.0   19  Female     Urban           108.0        224.5  27.5        67.0
# 5   6.0   32  Female     Rural           104.3        257.4  17.6        60.0
# 6   7.0   50    Male  Suburban           116.8        206.9  27.9        75.0
# 7   8.0   30  Female     Rural           100.3        268.0  14.5        68.0
# 8   9.0   34    Male     Urban           131.8        244.6  24.4        65.0
# 9  10.0   22    Male     Rural           138.3        196.7  17.5        88.0
#
#   Exercise_Level Smoking  ... Income_Level Physical_Activity Education_Level  \
# ...

# %%
data.tail()
# Out:
#             ID  Age  Gender    Region  Blood_Pressure  Cholesterol   BMI  \
# 49995  49996.0   56   Other     Rural            87.7        256.8  25.3
# 49996  49997.0   16    Male     Rural           125.2        102.9  25.1
# 49997  49998.0   46  Female  Suburban           116.2        160.6  27.7
# 49998  49999.0   24  Female     Rural           104.6        180.4  29.2
# 49999  50000.0   38    Male     Urban           122.9         89.2  21.8
#
#        Heart_Rate Exercise_Level Smoking  ... Income_Level Physical_Activity  \
# 49995        71.0            Low    True  ...       Middle              High
# 49996        77.0       Moderate    True  ...       Middle              High
# 49997        63.0            Low    True  ...       Middle               Low
# 49998        60.0       Moderate    True  ...          Low          Moderate
# 49999        69.0       Moderate   False  ...          Low          Moderate
#
# ...

# %% [markdown]
# ## **get the datatypes**

# %%
data.dtypes
# Out:
# ID                       float64
# Age                        int64
# Gender                    object
# Region                    object
# Blood_Pressure           float64
# Cholesterol              float64
# BMI                      float64
# Heart_Rate               float64
# Exercise_Level            object
# Smoking                   object
# Alcohol_Consumption       object
# Diabetes                  object
# Family_History            object
# Stress_Level             float64
# Heart_Attack              object
# Angina                    object
# Heart_Disease_History     object
# Diet                      object
# Sleep_Hours              float64
# Occupation                object
# Income_Level              object
# Physical_Activity         object
# Education_Level           object
# Marital_Status            object
# Urban_Rural               object
# Medication                object
# Health_Awareness         float64
# Daily_Water_Intake       float64
# ...

# %% [markdown]
# ## **num.of rows and columns**

# %%
data.shape
# Out:
# (50000, 30)

# %% [markdown]
# ## **get the total num. of null values in complete table**

# %%
data.isnull().sum().sum()
# Out:
# np.int64(27152)

# %% [markdown]
# ## **no. of null values per row n column**

# %%
data.isnull().sum()
# Out:
# ID                          30
# Age                          0
# Gender                       0
# Region                      28
# Blood_Pressure              31
# Cholesterol                  0
# BMI                          0
# Heart_Rate                  91
# Exercise_Level             180
# Smoking                    103
# Alcohol_Consumption      25096
# Diabetes                   103
# Family_History             103
# Stress_Level               114
# Heart_Attack               103
# Angina                     142
# Heart_Disease_History       71
# Diet                        71
# Sleep_Hours                 71
# Occupation                 138
# Income_Level                71
# Physical_Activity           70
# Education_Level             70
# Marital_Status              95
# Urban_Rural                 94
# Medication                  69
# Health_Awareness            69
# Daily_Water_Intake          69
# Mental_Health               69
# Obesity                      1
# ...

# %%
data.isnull().sum()/data.shape[0]
# Out:
# ID                       0.00060
# Age                      0.00000
# Gender                   0.00000
# Region                   0.00056
# Blood_Pressure           0.00062
# Cholesterol              0.00000
# BMI                      0.00000
# Heart_Rate               0.00182
# Exercise_Level           0.00360
# Smoking                  0.00206
# Alcohol_Consumption      0.50192
# Diabetes                 0.00206
# Family_History           0.00206
# Stress_Level             0.00228
# Heart_Attack             0.00206
# Angina                   0.00284
# Heart_Disease_History    0.00142
# Diet                     0.00142
# Sleep_Hours              0.00142
# Occupation               0.00276
# Income_Level             0.00142
# Physical_Activity        0.00140
# Education_Level          0.00140
# Marital_Status           0.00190
# Urban_Rural              0.00188
# Medication               0.00138
# Health_Awareness         0.00138
# Daily_Water_Intake       0.00138
# ...

# %%
data.notnull().sum().sum()
# Out:
# np.int64(1472848)

# %% [markdown]
# ## **% of null  values**

# %%
(data.isnull().sum().sum()/(data.shape[0]*data.shape[1]))*100
# Out:
# np.float64(1.8101333333333334)

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# ID                        0.060
# Age                       0.000
# Gender                    0.000
# Region                    0.056
# Blood_Pressure            0.062
# Cholesterol               0.000
# BMI                       0.000
# Heart_Rate                0.182
# Exercise_Level            0.360
# Smoking                   0.206
# Alcohol_Consumption      50.192
# Diabetes                  0.206
# Family_History            0.206
# Stress_Level              0.228
# Heart_Attack              0.206
# Angina                    0.284
# Heart_Disease_History     0.142
# Diet                      0.142
# Sleep_Hours               0.142
# Occupation                0.276
# Income_Level              0.142
# Physical_Activity         0.140
# Education_Level           0.140
# Marital_Status            0.190
# Urban_Rural               0.188
# Medication                0.138
# Health_Awareness          0.138
# Daily_Water_Intake        0.138
# Mental_Health             0.138
# ...

# %% [markdown]
# ## **graphical rep.of nullvalues**

# %%
sns.heatmap(data.isnull())
plt.show()
